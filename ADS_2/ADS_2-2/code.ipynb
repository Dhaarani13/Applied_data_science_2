# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Multimodal_IMDB_dataset/Images/tmp/Multimodal_IMDB_dataset/
# Out:
# mkdir: cannot create directory ‘/tmp/Multimodal_IMDB_dataset’: File exists
# rsync: [sender] change_dir "/content/drive/MyDrive/Multimodal_IMDB_dataset/Multimodal_IMDB_dataset/Images/tmp/Multimodal_IMDB_dataset" failed: No such file or directory (2)
#               0 100%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/0)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1338) [sender=3.2.7]

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres /content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset (1)/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset (1)/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):

    image = tf.image.convert_image_dtype(image, dtype=tf.float32)

    # Resize the image to 64x64 pixels
    image = tf.image.resize(image, [64, 64])

    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

# Batch size
batch_size = 64

# Parse and process the training dataset with batch vectorization
posters_train_ds = (
    list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse images
    .batch(batch_size)  # Batch the dataset
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Process the batch
    .cache()  # Cache for performance
    .shuffle(buffer_size=1000)  # Shuffle for randomness
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# Parse and process the validation dataset with batch vectorization
posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse images
    .batch(batch_size)  # Batch the dataset
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Process the batch
    .cache()  # Cache for performance
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

# Batch size
batch_size = 64

# Placeholder for preprocessing function (e.g., tokenization)
def process_text(text, label):
    # Convert text to lower case, strip whitespace, or apply tokenization
    text = tf.strings.lower(text)
    text = tf.strings.strip(text)
    return text, label

# Training dataset
overviews_train_ds = (
    list_overviews_train_ds
    .map(process_text, num_parallel_calls=tf.data.AUTOTUNE)  # Process text
    .batch(batch_size)  # Batch the dataset
    .cache()  # Cache for performance
    .shuffle(buffer_size=1000)  # Shuffle for randomness
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# Validation dataset
overviews_valid_ds = (
    list_overviews_valid_ds
    .map(process_text, num_parallel_calls=tf.data.AUTOTUNE)  # Process text
    .batch(batch_size)  # Batch the dataset
    .cache()  # Cache for performance
    .prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch to improve latency
)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
import tensorflow as tf

# Constants
VOCAB_SIZE = 10000  # Set the desired vocabulary size
SEQUENCE_LENGTH = 100  # Define a fixed sequence length
BATCH_SIZE = 64  # Batch size for loading data

# Define the TextVectorization layer with output_sequence_length
encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE,  # Limit the size of the vocabulary
    output_mode='int',  # Convert tokens to integers
    output_sequence_length=SEQUENCE_LENGTH  # Pad/truncate to a fixed length
)

# Process the training dataset: map the overview (text) and label separately
overviews_train_ds_processed = (
    list_overviews_train_ds
    .map(lambda overview, label: overview)  # Extract only the overview text
    .batch(BATCH_SIZE)  # Apply batching first
)

# Adapt the encoder to the training dataset
encoder.adapt(overviews_train_ds_processed)

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.
# Get the vocabulary from the encoder
vocabulary = encoder.get_vocabulary()

# Print the first 200 words (tokens) of the vocabulary
print(vocabulary[:200])
# Out:
# ['', '[UNK]', 'a', 'the', 'to', 'of', 'and', 'in', 'his', 'is', 'an', 'with', 'her', 'for', 'he', 'on', 'their', 'who', 'by', 'from', 'when', 'as', 'that', 'after', 'young', 'life', 'man', 'they', 'him', 'new', 'at', 'two', 'are', 'but', 'into', 'has', 'she', 'up', 'family', 'love', 'one', 'woman', 'out', 'find', 'must', 'it', 'be', 'finds', 'friends', 'school', 'story', 'world', 'them', 'about', 'while', 'where', 'girl', 'have', 'group', 'years', 'lives', 'father', 'home', 'wife', 'becomes', 'war', 'during', 'help', 'city', 'back', 'get', 'three', 'town', 'only', 'himself', 'boy', 'all', 'high', 'which', 'york', 'team', 'son', 'gets', 'against', 'time', 'other', 'between', 'mother', 'falls', 'down', 'police', 'former', 'own', 'murder', 'takes', 'can', 'its', 'become', 'american', 'tries', 'friend', 'daughter', 'order', 'will', 'being', 'before', 'old', 'college', 'was', 'this', 'take', 'save', 'agent', 'set', 'small', 'death', 'over', 'relationship', 'off', 'not', 'goes', 'way', 'through', 'couple', 'together', 'meets', 'husband', 'more', 'killer', 'each', 'first', 'mysterious', 'people', 'make', 'day', 'begins', 'go', 'been', 'discovers', 'brother', 'stop', 'hes', 'returns', 'best', 'secret', 'job', 'house', 'forced', 'detective', 'comes', 'now', 'four', 'work', 'what', 'local', 'past', 'married', 'just', 'us', 'living', 'cop', 'parents', 'drug', 'trying', 'turns', 'or', 'men', 'evil', 'whose', 'teenage', 'soon', 'black', 'another', 'student', 'movie', 'live', 'than', 'discover', 'children', 'so', 'sister', 'crime', 'film', 'herself', 'fight', 'sent', 'prison', 'most', 'killed', 'earth', 'decides', 'trip', 'some', 'series', 'officer', 'battle', 'try', 'true', 'brothers', 'both']

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.
def build_cnn_model():
    # Input layer
    inputs = Input(shape=(64, 64, 3), name="Input")

    # Conv0 and Drop1
    x = Conv2D(filters=16, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu", name="Conv0")(inputs)
    x = Dropout(rate=0.2, name="Drop1")(x)

    # Conv1, Conv2, Drop2, and Pool1
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(x)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(x)
    x = Dropout(rate=0.2, name="Drop2")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool1")(x)

    # Conv3, Conv4, Drop3, and Pool2
    x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
    x = Dropout(rate=0.2, name="Drop3")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool2")(x)

    # Conv5, Conv6, Drop4, and Pool3
    x = Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(x)
    x = Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
    x = Dropout(rate=0.2, name="Drop4")(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="Pool3")(x)

    # Flatten Layer
    x = Flatten(name="Flat")(x)

    # Fully Connected Layers with Dropout
    x = Dense(units=1024, activation="relu", name="FC1")(x)
    x = Dropout(rate=0.5, name="Drop5")(x)
    x = Dense(units=1024, activation="relu", name="FC2")(x)
    x = Dropout(rate=0.5, name="Drop6")(x)

    # Output Layer
    outputs = Dense(units=25, activation="sigmoid", name="Output")(x)

    # Create Model
    model = Model(inputs=inputs, outputs=outputs, name="model")

    return model

# Build and summarize the model
cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

#Complete here
cnn_model.summary()
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile (
    optimizer=Adam(learning_rate=1e-4),  # Adam optimizer with learning rate 1e-4
    loss="binary_crossentropy",         # Binary crossentropy loss
    metrics=[Precision(name="precision"), Recall(name="recall")]  # Precision and Recall as metrics
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

vocab_size = len(encoder.get_vocabulary())
# Create a Sequential model and add the embedding layer
embedder = Sequential([
    Embedding(
        input_dim=vocab_size,  # Length of the vocabulary
        output_dim=256,        # Output dimensions
        mask_zero=True,        # Mask padding tokens (index 0)
        name="Embedding"
    )
])

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
import tensorflow as tf

# Build the Sequential model
lstm_model = tf.keras.Sequential([
    encoder,  # The encoder that processes the text (assumed to be defined elsewhere)
    embedder,  # The embedding layer defined earlier
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256,
                                                      dropout=0.5,
                                                      recurrent_dropout=0.2,
                                                      return_sequences=True)),  # First BiLSTM layer
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,
                                                      dropout=0.5,
                                                      recurrent_dropout=0.2)),  # Second BiLSTM layer
    tf.keras.layers.Dense(128, activation='relu'),  # Dense layer with ReLU activation
    tf.keras.layers.Dropout(0.8),  # Dropout layer with rate 0.8
    tf.keras.layers.Dense(25, activation='sigmoid')  # Output layer with 25 units (for multi-label classification)
])

# Build the model with the input shape (None,) since the input is variable length text
lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
# Print the model summary to confirm the architecture
lstm_model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization_3                 │ (None, 100)                 │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_6 (Sequential)            │ (None, 100, 256)            │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_6 (Bidirectional)      │ (None, 100, 512)            │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_7 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

# Compile the model
lstm_model.compile(
    loss="binary_crossentropy",  # Loss function for multi-label classification
    optimizer=Adam(learning_rate=1e-4),  # Adam optimizer with learning rate of 1e-4
    metrics=[Precision(), Recall()]  # Precision and Recall as metrics
)

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the file paths where the best weights will be saved
checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

# Create the ModelCheckpoint callback for the CNN model
checkpoint_cnn_callback = ModelCheckpoint(
    checkpoint_cnn_filepath,       # Save the weights to this file
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only the best model (lowest validation loss)
    mode='min',                    # Minimize the validation loss
    save_weights_only=True,        # Save only the weights, not the full model
    verbose=1                      # Show a message when the model is saved
)

# Create the ModelCheckpoint callback for the LSTM model
checkpoint_lstm_callback = ModelCheckpoint(
    checkpoint_lstm_filepath,      # Save the weights to this file
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only the best model (lowest validation loss)
    mode='min',                    # Minimize the validation loss
    save_weights_only=True,        # Save only the weights, not the full model
    verbose=1                      # Show a message when the model is saved
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"
from tensorflow.keras.callbacks import LearningRateScheduler

# Provided function to adjust the learning rate during training
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)  # Keep the learning rate constant for the first 10 epochs
    else:
        return float(lr * tf.math.exp(-0.01))  # Decay the learning rate after epoch 10

# Create the LearningRateScheduler callback using the scheduler function
lr_callback = LearningRateScheduler(scheduler,verbose=1)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
# Train the CNN model for 40 epochs, using the callbacks created earlier
cnn_history = cnn_model.fit(
    posters_train_ds,            # Training dataset
    epochs=40,                   # Train for 40 epochs
    validation_data=posters_valid_ds,  # Validation dataset
    callbacks=[checkpoint_cnn_callback, lr_callback],  # Callbacks: checkpoint and learning rate scheduler
    verbose=1                     # Print training progress
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.4030 - precision: 0.2965 - recall: 0.2998
# Epoch 1: val_loss improved from inf to 0.34508, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 32s 148ms/step - loss: 0.4019 - precision: 0.2974 - recall: 0.2993 - val_loss: 0.3451 - val_precision: 0.5464 - val_recall: 0.3406 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2527 - precision: 0.4947 - recall: 0.2374
# Epoch 2: val_loss improved from 0.34508 to 0.32903, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - loss: 0.2527 - precision: 0.4948 - recall: 0.2373 - val_loss: 0.3290 - val_precision: 0.5307 - val_recall: 0.2232 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2469 - precision: 0.5366 - recall: 0.2240
# Epoch 3: val_loss improved from 0.32903 to 0.31830, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2468 - precision: 0.5368 - recall: 0.2243 - val_loss: 0.3183 - val_precision: 0.5648 - val_recall: 0.2824 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2361 - precision: 0.5552 - recall: 0.2627
# Epoch 4: val_loss did not improve from 0.31830
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2361 - precision: 0.5553 - recall: 0.2628 - val_loss: 0.3188 - val_precision: 0.5645 - val_recall: 0.3386 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2378 - precision: 0.5604 - recall: 0.2625
# Epoch 5: val_loss improved from 0.31830 to 0.30077, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2378 - precision: 0.5604 - recall: 0.2625 - val_loss: 0.3008 - val_precision: 0.5657 - val_recall: 0.3317 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2333 - precision: 0.5630 - recall: 0.2790
# Epoch 6: val_loss improved from 0.30077 to 0.29539, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2333 - precision: 0.5631 - recall: 0.2786 - val_loss: 0.2954 - val_precision: 0.5666 - val_recall: 0.3165 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2317 - precision: 0.5720 - recall: 0.2800
# Epoch 7: val_loss improved from 0.29539 to 0.29129, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2317 - precision: 0.5719 - recall: 0.2796 - val_loss: 0.2913 - val_precision: 0.5540 - val_recall: 0.2682 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2318 - precision: 0.5641 - recall: 0.2725
# Epoch 8: val_loss improved from 0.29129 to 0.28290, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2318 - precision: 0.5643 - recall: 0.2725 - val_loss: 0.2829 - val_precision: 0.5638 - val_recall: 0.3069 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2292 - precision: 0.5854 - recall: 0.2717
# Epoch 9: val_loss improved from 0.28290 to 0.28058, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2292 - precision: 0.5853 - recall: 0.2719 - val_loss: 0.2806 - val_precision: 0.5657 - val_recall: 0.3032 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2266 - precision: 0.5811 - recall: 0.2886
# Epoch 10: val_loss improved from 0.28058 to 0.28017, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2268 - precision: 0.5807 - recall: 0.2879 - val_loss: 0.2802 - val_precision: 0.5639 - val_recall: 0.2946 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 11/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2296 - precision: 0.5675 - recall: 0.2826
# Epoch 11: val_loss improved from 0.28017 to 0.26600, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2296 - precision: 0.5680 - recall: 0.2825 - val_loss: 0.2660 - val_precision: 0.5566 - val_recall: 0.2731 - learning_rate: 9.9005e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 12/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2294 - precision: 0.5818 - recall: 0.2854
# Epoch 12: val_loss did not improve from 0.26600
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2294 - precision: 0.5823 - recall: 0.2855 - val_loss: 0.2686 - val_precision: 0.5654 - val_recall: 0.2930 - learning_rate: 9.8020e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 13/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2256 - precision: 0.5889 - recall: 0.2860
# Epoch 13: val_loss improved from 0.26600 to 0.26280, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2256 - precision: 0.5889 - recall: 0.2860 - val_loss: 0.2628 - val_precision: 0.5636 - val_recall: 0.2844 - learning_rate: 9.7045e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 14/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2275 - precision: 0.5843 - recall: 0.2753
# Epoch 14: val_loss did not improve from 0.26280
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2274 - precision: 0.5846 - recall: 0.2756 - val_loss: 0.2628 - val_precision: 0.5716 - val_recall: 0.3128 - learning_rate: 9.6079e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 15/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2263 - precision: 0.5943 - recall: 0.2966
# Epoch 15: val_loss improved from 0.26280 to 0.25536, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2263 - precision: 0.5943 - recall: 0.2960 - val_loss: 0.2554 - val_precision: 0.5583 - val_recall: 0.2646 - learning_rate: 9.5123e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 16/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2240 - precision: 0.5857 - recall: 0.3007
# Epoch 16: val_loss did not improve from 0.25536
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2240 - precision: 0.5861 - recall: 0.3001 - val_loss: 0.2596 - val_precision: 0.5375 - val_recall: 0.2302 - learning_rate: 9.4176e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 17/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2216 - precision: 0.6042 - recall: 0.3031
# Epoch 17: val_loss improved from 0.25536 to 0.25327, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2217 - precision: 0.6041 - recall: 0.3027 - val_loss: 0.2533 - val_precision: 0.5338 - val_recall: 0.2245 - learning_rate: 9.3239e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 18/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2247 - precision: 0.6033 - recall: 0.2845
# Epoch 18: val_loss did not improve from 0.25327
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2246 - precision: 0.6039 - recall: 0.2847 - val_loss: 0.2546 - val_precision: 0.5340 - val_recall: 0.2259 - learning_rate: 9.2312e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 19/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2206 - precision: 0.6324 - recall: 0.2924
# Epoch 19: val_loss did not improve from 0.25327
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2206 - precision: 0.6319 - recall: 0.2921 - val_loss: 0.2604 - val_precision: 0.5495 - val_recall: 0.2259 - learning_rate: 9.1393e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 20/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2207 - precision: 0.6408 - recall: 0.2833
# Epoch 20: val_loss did not improve from 0.25327
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2207 - precision: 0.6403 - recall: 0.2836 - val_loss: 0.2584 - val_precision: 0.5552 - val_recall: 0.2179 - learning_rate: 9.0484e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 8.95834164111875e-05.
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2211 - precision: 0.6427 - recall: 0.2754
# Epoch 21: val_loss improved from 0.25327 to 0.25320, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2212 - precision: 0.6425 - recall: 0.2755 - val_loss: 0.2532 - val_precision: 0.5623 - val_recall: 0.2388 - learning_rate: 8.9583e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 8.86920461198315e-05.
# Epoch 22/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2207 - precision: 0.6434 - recall: 0.2820
# Epoch 22: val_loss did not improve from 0.25320
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2207 - precision: 0.6430 - recall: 0.2821 - val_loss: 0.2603 - val_precision: 0.5580 - val_recall: 0.2388 - learning_rate: 8.8692e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 8.78095452208072e-05.
# Epoch 23/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2169 - precision: 0.6521 - recall: 0.2869
# Epoch 23: val_loss improved from 0.25320 to 0.24892, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2170 - precision: 0.6517 - recall: 0.2868 - val_loss: 0.2489 - val_precision: 0.5671 - val_recall: 0.2292 - learning_rate: 8.7810e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 8.69358264026232e-05.
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2176 - precision: 0.6343 - recall: 0.2697
# Epoch 24: val_loss did not improve from 0.24892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2176 - precision: 0.6344 - recall: 0.2699 - val_loss: 0.2589 - val_precision: 0.5669 - val_recall: 0.2368 - learning_rate: 8.6936e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 8.607080235378817e-05.
# Epoch 25/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2185 - precision: 0.6406 - recall: 0.2829
# Epoch 25: val_loss did not improve from 0.24892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2185 - precision: 0.6409 - recall: 0.2832 - val_loss: 0.2538 - val_precision: 0.5798 - val_recall: 0.2464 - learning_rate: 8.6071e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 8.521438576281071e-05.
# Epoch 26/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2175 - precision: 0.6507 - recall: 0.2803
# Epoch 26: val_loss did not improve from 0.24892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2175 - precision: 0.6507 - recall: 0.2804 - val_loss: 0.2502 - val_precision: 0.5472 - val_recall: 0.2302 - learning_rate: 8.5214e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 8.436648931819946e-05.
# Epoch 27/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2171 - precision: 0.6528 - recall: 0.2947
# Epoch 27: val_loss did not improve from 0.24892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2171 - precision: 0.6530 - recall: 0.2944 - val_loss: 0.2548 - val_precision: 0.5504 - val_recall: 0.2292 - learning_rate: 8.4366e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 8.352702570846304e-05.
# Epoch 28/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2171 - precision: 0.6523 - recall: 0.2957
# Epoch 28: val_loss did not improve from 0.24892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2171 - precision: 0.6524 - recall: 0.2956 - val_loss: 0.2514 - val_precision: 0.5827 - val_recall: 0.2318 - learning_rate: 8.3527e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 8.269591489806771e-05.
# Epoch 29/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2139 - precision: 0.6632 - recall: 0.2918
# Epoch 29: val_loss improved from 0.24892 to 0.24784, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2139 - precision: 0.6632 - recall: 0.2917 - val_loss: 0.2478 - val_precision: 0.5721 - val_recall: 0.2282 - learning_rate: 8.2696e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 8.187307685147971e-05.
# Epoch 30/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2146 - precision: 0.6660 - recall: 0.2946
# Epoch 30: val_loss improved from 0.24784 to 0.24191, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2146 - precision: 0.6659 - recall: 0.2945 - val_loss: 0.2419 - val_precision: 0.5848 - val_recall: 0.2464 - learning_rate: 8.1873e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 8.105842425720766e-05.
# Epoch 31/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2138 - precision: 0.6543 - recall: 0.2943
# Epoch 31: val_loss did not improve from 0.24191
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2138 - precision: 0.6544 - recall: 0.2943 - val_loss: 0.2499 - val_precision: 0.5639 - val_recall: 0.2292 - learning_rate: 8.1058e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 8.025187707971781e-05.
# Epoch 32/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2123 - precision: 0.6695 - recall: 0.2895
# Epoch 32: val_loss did not improve from 0.24191
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2123 - precision: 0.6692 - recall: 0.2896 - val_loss: 0.2483 - val_precision: 0.5674 - val_recall: 0.2282 - learning_rate: 8.0252e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 7.945335528347641e-05.
# Epoch 33/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2140 - precision: 0.6668 - recall: 0.2908
# Epoch 33: val_loss did not improve from 0.24191
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2139 - precision: 0.6669 - recall: 0.2909 - val_loss: 0.2427 - val_precision: 0.5723 - val_recall: 0.2292 - learning_rate: 7.9453e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.86627788329497e-05.
# Epoch 34/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2119 - precision: 0.6703 - recall: 0.2907
# Epoch 34: val_loss did not improve from 0.24191
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2120 - precision: 0.6702 - recall: 0.2907 - val_loss: 0.2452 - val_precision: 0.5787 - val_recall: 0.2467 - learning_rate: 7.8663e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 7.788007496856153e-05.
# Epoch 35/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2123 - precision: 0.6677 - recall: 0.2946
# Epoch 35: val_loss did not improve from 0.24191
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2123 - precision: 0.6676 - recall: 0.2946 - val_loss: 0.2481 - val_precision: 0.5657 - val_recall: 0.2434 - learning_rate: 7.7880e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.710515637882054e-05.
# Epoch 36/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2118 - precision: 0.6592 - recall: 0.2967
# Epoch 36: val_loss improved from 0.24191 to 0.24044, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2118 - precision: 0.6595 - recall: 0.2967 - val_loss: 0.2404 - val_precision: 0.5783 - val_recall: 0.2503 - learning_rate: 7.7105e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.633795030415058e-05.
# Epoch 37/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2109 - precision: 0.6692 - recall: 0.3019
# Epoch 37: val_loss did not improve from 0.24044
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2109 - precision: 0.6692 - recall: 0.3017 - val_loss: 0.2452 - val_precision: 0.5745 - val_recall: 0.2321 - learning_rate: 7.6338e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.55783767090179e-05.
# Epoch 38/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2101 - precision: 0.6827 - recall: 0.3047
# Epoch 38: val_loss did not improve from 0.24044
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2101 - precision: 0.6823 - recall: 0.3046 - val_loss: 0.2478 - val_precision: 0.5827 - val_recall: 0.2354 - learning_rate: 7.5578e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.482636283384636e-05.
# Epoch 39/40
#  1/80 ━━━━━━━━━━━━━━━━━━━━ 35s 448ms/step - loss: 0.2118 - precision: 0.6792 - recall: 0.2384

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall


lstm_history = lstm_model.fit(
    overviews_train_ds,             # Training dataset for overviews
    epochs=20,
    # Train for 20 epochs
    validation_data=overviews_valid_ds,  # Validation dataset for overviews
    callbacks=[checkpoint_lstm_callback, lr_callback],  # Callbacks: checkpoint and learning rate scheduler
    verbose=1                        # Print training progress
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/20
# Exception ignored in: <function _xla_gc_callback at 0x7c73926c3250>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.6630 - precision_2: 0.1034 - recall_2: 0.3641
# Epoch 1: val_loss improved from inf to 0.38534, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - loss: 0.6623 - precision_2: 0.1035 - recall_2: 0.3633 - val_loss: 0.3853 - val_precision_2: 0.3000 - val_recall_2: 9.8393e-04 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4753 - precision_2: 0.1404 - recall_2: 0.2403
# Epoch 2: val_loss improved from 0.38534 to 0.31316, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - loss: 0.4752 - precision_2: 0.1405 - recall_2: 0.2403 - val_loss: 0.3132 - val_precision_2: 0.4481 - val_recall_2: 0.1853 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4222 - precision_2: 0.1836 - recall_2: 0.2396
# Epoch 3: val_loss improved from 0.31316 to 0.27877, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.4220 - precision_2: 0.1837 - recall_2: 0.2396 - val_loss: 0.2788 - val_precision_2: 1.0000 - val_recall_2: 3.2798e-04 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3843 - precision_2: 0.2204 - recall_2: 0.2277
# Epoch 4: val_loss improved from 0.27877 to 0.26564, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.3842 - precision_2: 0.2205 - recall_2: 0.2277 - val_loss: 0.2656 - val_precision_2: 1.0000 - val_recall_2: 3.2798e-04 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3623 - precision_2: 0.2501 - recall_2: 0.2181
# Epoch 5: val_loss improved from 0.26564 to 0.25742, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.3622 - precision_2: 0.2503 - recall_2: 0.2182 - val_loss: 0.2574 - val_precision_2: 1.0000 - val_recall_2: 3.2798e-04 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3429 - precision_2: 0.2923 - recall_2: 0.2273
# Epoch 6: val_loss improved from 0.25742 to 0.25235, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.3428 - precision_2: 0.2924 - recall_2: 0.2272 - val_loss: 0.2524 - val_precision_2: 0.5434 - val_recall_2: 0.1705 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3272 - precision_2: 0.3296 - recall_2: 0.2289
# Epoch 7: val_loss improved from 0.25235 to 0.24886, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.3272 - precision_2: 0.3296 - recall_2: 0.2288 - val_loss: 0.2489 - val_precision_2: 0.5480 - val_recall_2: 0.2020 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3160 - precision_2: 0.3481 - recall_2: 0.2292
# Epoch 8: val_loss improved from 0.24886 to 0.24738, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.3160 - precision_2: 0.3481 - recall_2: 0.2291 - val_loss: 0.2474 - val_precision_2: 0.5660 - val_recall_2: 0.1617 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3095 - precision_2: 0.3649 - recall_2: 0.2168
# Epoch 9: val_loss improved from 0.24738 to 0.24492, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.3094 - precision_2: 0.3649 - recall_2: 0.2167 - val_loss: 0.2449 - val_precision_2: 0.5431 - val_recall_2: 0.2253 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3050 - precision_2: 0.3702 - recall_2: 0.2026
# Epoch 10: val_loss improved from 0.24492 to 0.24318, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.3049 - precision_2: 0.3703 - recall_2: 0.2027 - val_loss: 0.2432 - val_precision_2: 0.5431 - val_recall_2: 0.2253 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2992 - precision_2: 0.3821 - recall_2: 0.2025
# Epoch 11: val_loss improved from 0.24318 to 0.24163, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.2991 - precision_2: 0.3823 - recall_2: 0.2026 - val_loss: 0.2416 - val_precision_2: 0.5431 - val_recall_2: 0.2253 - learning_rate: 9.9005e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 995ms/step - loss: 0.2894 - precision_2: 0.4112 - recall_2: 0.2182
# Epoch 12: val_loss improved from 0.24163 to 0.23948, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.2893 - precision_2: 0.4113 - recall_2: 0.2182 - val_loss: 0.2395 - val_precision_2: 0.5546 - val_recall_2: 0.2214 - learning_rate: 9.8020e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2847 - precision_2: 0.4229 - recall_2: 0.2198
# Epoch 13: val_loss improved from 0.23948 to 0.23624, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.2846 - precision_2: 0.4230 - recall_2: 0.2199 - val_loss: 0.2362 - val_precision_2: 0.5895 - val_recall_2: 0.2096 - learning_rate: 9.7045e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2748 - precision_2: 0.4414 - recall_2: 0.2220
# Epoch 14: val_loss improved from 0.23624 to 0.23377, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - loss: 0.2748 - precision_2: 0.4415 - recall_2: 0.2220 - val_loss: 0.2338 - val_precision_2: 0.6346 - val_recall_2: 0.1988 - learning_rate: 9.6079e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2708 - precision_2: 0.4665 - recall_2: 0.2336
# Epoch 15: val_loss improved from 0.23377 to 0.23170, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.2708 - precision_2: 0.4666 - recall_2: 0.2337 - val_loss: 0.2317 - val_precision_2: 0.6148 - val_recall_2: 0.2512 - learning_rate: 9.5123e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - loss: 0.2634 - precision_2: 0.4886 - recall_2: 0.2486
# Epoch 16: val_loss improved from 0.23170 to 0.22927, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.2634 - precision_2: 0.4887 - recall_2: 0.2487 - val_loss: 0.2293 - val_precision_2: 0.6210 - val_recall_2: 0.2584 - learning_rate: 9.4176e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2627 - precision_2: 0.4889 - recall_2: 0.2569
# Epoch 17: val_loss did not improve from 0.22927
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.2627 - precision_2: 0.4889 - recall_2: 0.2569 - val_loss: 0.2296 - val_precision_2: 0.6079 - val_recall_2: 0.2735 - learning_rate: 9.3239e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1000ms/step - loss: 0.2572 - precision_2: 0.5103 - recall_2: 0.2654
# Epoch 18: val_loss improved from 0.22927 to 0.22701, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - loss: 0.2572 - precision_2: 0.5103 - recall_2: 0.2654 - val_loss: 0.2270 - val_precision_2: 0.6197 - val_recall_2: 0.2453 - learning_rate: 9.2312e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2538 - precision_2: 0.5187 - recall_2: 0.2632
# Epoch 19: val_loss improved from 0.22701 to 0.22592, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.2538 - precision_2: 0.5188 - recall_2: 0.2634 - val_loss: 0.2259 - val_precision_2: 0.6420 - val_recall_2: 0.2217 - learning_rate: 9.1393e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2498 - precision_2: 0.5322 - recall_2: 0.2807
# Epoch 20: val_loss did not improve from 0.22592
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.2497 - precision_2: 0.5322 - recall_2: 0.2807 - val_loss: 0.2262 - val_precision_2: 0.6099 - val_recall_2: 0.2703 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i
# Plot for LSTM model loss


import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Loss
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=14)  # Increased label size
plt.ylabel('Loss', fontsize=14)  # Increased label size
plt.legend(fontsize=12)  # Increased legend font size

# Precision
plt.subplot(1, 2, 2)
plt.plot(cnn_history.history['precision'], label='Training Precision')
plt.plot(cnn_history.history['val_precision'], label='Validation Precision')
plt.title('Training and Validation Precision', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=14)  # Increased label size
plt.ylabel('Precision', fontsize=14)  # Increased label size
plt.legend(fontsize=12)  # Increased legend font size

# Show the plots
plt.tight_layout()
plt.show()

# Plotting recall
plt.figure(figsize=(12, 6))

plt.plot(cnn_history.history['recall'], label='Training Recall')
plt.plot(cnn_history.history['val_recall'], label='Validation Recall')
plt.title('Training and Validation Recall', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=14)  # Increased label size
plt.ylabel('Recall', fontsize=14)  # Increased label size
plt.legend(fontsize=12)  # Increased legend font size

plt.show()

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
import matplotlib.pyplot as plt

# Plotting the training and validation loss
plt.figure(figsize=(12, 6))

# Loss
plt.subplot(1, 2, 1)
plt.plot(lstm_history.history['loss'], label='Training Loss')
plt.plot(lstm_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=16)  # Increased label size
plt.ylabel('Loss', fontsize=16)  # Increased label size
plt.legend(fontsize=14)  # Increased legend font size

# Precision
plt.subplot(1, 2, 2)
plt.plot(lstm_history.history['precision_2'], label='Training Precision')
plt.plot(lstm_history.history['val_precision_2'], label='Validation Precision')
plt.title('Training and Validation Precision', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=16)  # Increased label size
plt.ylabel('Precision', fontsize=16)  # Increased label size
plt.legend(fontsize=14)  # Increased legend font size

# Show the plots
plt.tight_layout()
plt.show()

# Plotting recall
plt.figure(figsize=(12, 6))

plt.plot(lstm_history.history['recall_2'], label='Training Recall')
plt.plot(lstm_history.history['val_recall_2'], label='Validation Recall')
plt.title('Training and Validation Recall', fontsize=16)  # Increased title size
plt.xlabel('Epochs', fontsize=16)  # Increased label size
plt.ylabel('Recall', fontsize=16)  # Increased label size
plt.legend(fontsize=14)  # Increased legend font size

plt.show()

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c


#Complete here
import matplotlib.pyplot as plt
import numpy as np

# Load the best weights for both models
cnn_model.load_weights(checkpoint_cnn_filepath)
lstm_model.load_weights(checkpoint_lstm_filepath)

# Choose a few films (replace with actual indices from your dataset)
example_indices = [0, 1, 2]  # Example indices, replace with your desired film indices

# Function to get top 3 genres
def get_top_3_genres(predictions, genre_names):
    top_3_indices = np.argsort(predictions)[-3:][::-1]  # Get indices of top 3
    top_3_genres = [genre_names[i] for i in top_3_indices]
    return top_3_genres

# Assuming you have 'genre_names' available
genre_names = list(dataset.columns[3:])  # Assuming genres start from column index 3

for i in example_indices:
    # Assuming 'posters_train_ds' and 'overviews_train_ds' are tf.data.Datasets
    # Accessing elements from a tf.data.Dataset requires iteration:

    # Get the poster and overview for the current index
    for j, (image_batch, label_batch) in enumerate(posters_train_ds):
      if j == i:
        poster = image_batch[0] #Assuming one poster per batch for simplicity
        break

    for j, (overview_batch, label_batch) in enumerate(overviews_train_ds):
      if j == i:
        overview = overview_batch[0] # Assuming one overview per batch
        break

    # CNN prediction
    cnn_predictions = cnn_model.predict(np.expand_dims(poster, axis=0))
    top_3_cnn = get_top_3_genres(cnn_predictions[0], genre_names)


    # LSTM prediction
    lstm_predictions = lstm_model.predict(np.expand_dims(overview, axis=0))
    top_3_lstm = get_top_3_genres(lstm_predictions[0], genre_names)


    # Ground truth genres (replace with actual ground truth retrieval method)
    ground_truth = list(dataset.iloc[i][3:])
    ground_truth = [genre_names[idx] for idx, val in enumerate(ground_truth) if val == 1]

    # Plot the poster
    plt.imshow(poster)
    plt.title(f"Film {i}")
    plt.axis('off')
    plt.show()

    # Print the overview (handle potential errors gracefully)
    try:
        print("Overview:", dataset['Overview'].iloc[i][:200] + "...")
    except Exception as e:
        print(f"Error printing overview for film {i}: {e}")


    print("\nGround Truth Genres:", ground_truth)
    print("CNN's Top 3 Predicted Genres:", top_3_cnn)
    print("LSTM's Top 3 Predicted Genres:", top_3_lstm)
    print("-" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Overview: Follows hard-to-please Aurora looking for love, and her daughter's family problems....
#
# Ground Truth Genres: ['Comedy', 'Drama']
# CNN's Top 3 Predicted Genres: ['Family', 'Crime', 'Sci-Fi']
# LSTM's Top 3 Predicted Genres: ['Family', 'Crime', 'Adventure']
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Overview: A Pittsburgh woman with two jobs as a welder and an exotic dancer wants to get into ballet school....
#
# Ground Truth Genres: ['Drama', 'Music', 'Romance']
# CNN's Top 3 Predicted Genres: ['Family', 'Sci-Fi', 'Crime']
# LSTM's Top 3 Predicted Genres: ['Family', 'Crime', 'Sci-Fi']
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Overview: A snobbish investor and a wily street con artist find their positions reversed as part of a bet by two callous millionaires....
#
# Ground Truth Genres: ['Comedy']
# CNN's Top 3 Predicted Genres: ['Family', 'Sci-Fi', 'Crime']
# LSTM's Top 3 Predicted Genres: ['Family', 'Adventure', 'Crime']
# --------------------------------------------------
